# %%
import pandas as pd
import numpy as np

# %%
data_df = pd.read_csv("RayHudson.csv")

# %%
data_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                           Video Name  \
# 0  Barcelona SC (ECU) vs Flamengo (BRA) | LIBERTA...
# 1  Flamengo (BRA) vs Barcelona SC (ECU) | LIBERTA...
# 2  Barcelona SC (ECU) vs Fluminense (BRA) | LIBER...
# 3  Fluminense (BRA) vs SC Barcelona (ECU) | LIBER...
# 4  Barcelona vs Juventus | JOAN GAMPER HIGHLIGHTS...
#
#                                        Thumbnail URL     Video ID  \
# 0  https://i.ytimg.com/vi/P9E8RUSKD9c/hqdefault.j...  P9E8RUSKD9c
# 1  https://i.ytimg.com/vi/WzkHw0gClKc/hqdefault.j...  WzkHw0gClKc
# 2  https://i.ytimg.com/vi/qOJFdTSPBHs/hqdefault.j...  qOJFdTSPBHs
# 3  https://i.ytimg.com/vi/67RiQ9UxdRI/hqdefault.j...  67RiQ9UxdRI
# 4  https://i.ytimg.com/vi/gsiBERz7Jrw/hqdefault.j...  gsiBERz7Jrw
#
#                   length date published  \
# ...

# %% [markdown]
# remove:
#
# - LIBERTADORES
# - Barcelona SC

# %%
data_df = data_df[~data_df['Video Name'].str.contains("WOMEN")]

# %%
data_df.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1  \
# 4            4             4
# 10          10            10
# 14          14            14
# 16          16            16
# 17          17            17
#
#                                            Video Name  \
# 4   Barcelona vs Juventus | JOAN GAMPER HIGHLIGHTS...
# 10  Valencia vs FC Barcelona | LALIGA HIGHLIGHTS |...
# 14  Barcelona vs Getafe | LA LIGA HIGHLIGHTS | 4/2...
# 16     Ray Hudson's Best Reactions Vol. 2: El Clásico
# 17  Real Madrid vs Barcelona | LALIGA HIGHLIGHTS |...
#
#                                         Thumbnail URL     Video ID  \
# 4   https://i.ytimg.com/vi/gsiBERz7Jrw/hqdefault.j...  gsiBERz7Jrw
# 10  https://i.ytimg.com/vi/TSHwAnUFBJg/hqdefault.j...  TSHwAnUFBJg
# 14  https://i.ytimg.com/vi/P94-YkBNOII/hqdefault.j...  P94-YkBNOII
# 16  https://i.ytimg.com/vi/Q383qiSYFTA/hqdefault.j...  Q383qiSYFTA
# 17  https://i.ytimg.com/vi/tyOX9p2BWZk/hqdefault.j...  tyOX9p2BWZk
#
#                     length date published  \
# ...

# %%
data_df.to_csv("RayHudsonSanitized.csv")
