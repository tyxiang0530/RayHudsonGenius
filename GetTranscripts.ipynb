# %%
from youtube_transcript_api import YouTubeTranscriptApi
import nltk
from nltk.tokenize import word_tokenize
import string
import os
import pickle
from nltk.corpus import stopwords
from string import punctuation
from nltk.stem import WordNetLemmatizer
import io
import re
import numpy as np
import csv
import pandas as pd

# %%
def fetch_transcripts(video_id):
    try:
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
        try:
            full_trans = ''
            transcript = transcript_list.find_transcript(['en', 'en-US'])
            text_list = transcript.fetch()
            for chunk in text_list:
                print(chunk)
                full_trans += ' ' + chunk['text']
            return full_trans
        except Exception as e:
            print(e)
            try:
            # if the transcript is not in english, autogenerate english captions from that language
                transcript = transcript_list.find_transcript([
                    'de', 'zh_Hans', 'fr', 'zh-Hant', 'es',
                    'ar', 'hi', 'it', 'ru', 'vi', 'th', 'sv',
                    'fa', 'pt', 'cs', 'na', 'nl', 'el', 'fil', 'zh-TW'
                ])
                full_trans = ''
                translated_transcript = transcript.translate('en')
                for text in translated_transcript:
                    full_trans += ' ' + text['text']
                return full_trans
            except Exception as e:
                print(e)
                translated_transcript = ''
                return translated_transcript
    except Exception as e:
        print(e)
        return ''

# %%
rag_df = pd.read_csv("RayHudson.csv")
rag_df.head()
# %%
rag_df['transcript'] = rag_df['Video ID'].apply(fetch_transcripts)


# %%
rag_df.head()
rag_df.to_csv("RayHudson.csv")
# Out:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=P9E8RUSKD9c! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ['en', 'en-US']
#
# For this video (P9E8RUSKD9c) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - es ("Spanish (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - ne ("Nepali")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - or ("Odia")
#  - om ("Oromo")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - ti ("Tigrinya")
#  - ts ("Tsonga")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - und ("Unknown Language")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - vi ("Vietnamese")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 'Transcript' object is not iterable
# {'text': '[Applause]', 'start': 0.84, 'duration': 3.62}
# {'text': '[Music]', 'start': 5.81, 'duration': 3.14}
# {'text': 'and off we go in this semi-final first', 'start': 9.04, 'duration': 3.36}
# {'text': 'leg', 'start': 11.36, 'duration': 3.279}
# {'text': 'flamingo just three games away from a', 'start': 12.4, 'duration': 5.92}
# {'text': 'much coveted third libertadores title', 'start': 14.639, 'duration': 6.48}
# {'text': "that's a good delivery there's a shot oh", 'start': 18.32, 'duration': 6.0}
# {'text': 'fantastic save from elvis and again', 'start': 21.119, 'duration': 4.961}
# {'text': 'oh from bruno and', 'start': 24.32, 'duration': 4.4}
# {'text': 'those came out', 'start': 26.08, 'duration': 2.64}
# {'text': 'isla', 'start': 29.439, 'duration': 3.041}
# {'text': 'gabby goal everton ripero in the half', 'start': 30.64, 'duration': 4.24}
# {'text': 'space', 'start': 32.48, 'duration': 2.4}
# {'text': 'everton', 'start': 35.6, 'duration': 5.88}
# {'text': "it's got two to aim for", 'start': 37.44, 'duration': 4.04}
# {'text': "to play here's castillo fizzed in and", 'start': 45.92, 'duration': 5.2}
# {'text': 'saved once what can damian diaz conjure', 'start': 48.879, 'duration': 4.241}
# {'text': 'up here', 'start': 51.12, 'duration': 4.24}
# {'text': 'headed out buy it out', 'start': 53.12, 'duration': 4.24}
# {'text': 'virginia does the rest reclaimed by', 'start': 55.36, 'duration': 4.56}
# {'text': 'preciado', 'start': 57.36, 'duration': 4.64}
# {'text': 'nixon', 'start': 59.92, 'duration': 3.6}
# {'text': 'line one up', 'start': 62.0, 'duration': 3.76}
# {'text': 'martinez', 'start': 63.52, 'duration': 4.56}
# {'text': 'given away by castillo everton ribano', 'start': 65.76, 'duration': 5.039}
# {'text': "took a deflection it's saved", 'start': 68.08, 'duration': 3.7}
# {'text': 'bruno', 'start': 70.799, 'duration': 4.231}
# {'text': '[Applause]', 'start': 71.78, 'duration': 3.25}
# {'text': 'very far away from', 'start': 77.52, 'duration': 3.36}
# {'text': 'the real estate where he does the most', 'start': 79.36, 'duration': 4.0}
# {'text': 'damage but he picks up bruno inky and he', 'start': 80.88, 'duration': 6.96}
# {'text': 'draws first blood at the monaco', 'start': 83.36, 'duration': 4.48}
# {'text': 'flamingos top', 'start': 96.72, 'duration': 6.16}
# {'text': 'square has just delivered', 'start': 98.84, 'duration': 6.12}
# {'text': 'a pitch', 'start': 102.88, 'duration': 5.12}
# {'text': 'each perfect ball and a silver platter', 'start': 104.96, 'duration': 5.6}
# {'text': 'for bruno', 'start': 108.0, 'duration': 2.56}
# {'text': 'who left up in the clouds and beat', 'start': 110.64, 'duration': 7.819}
# {'text': '[Applause]', 'start': 114.77, 'duration': 3.689}
# {'text': 'a sumptuous delivery', 'start': 119.439, 'duration': 3.841}
# {'text': '[Applause]', 'start': 121.29, 'duration': 4.95}
# {'text': 'from number nine', 'start': 123.28, 'duration': 2.96}
# {'text': 'dispatch with extreme prejudice', 'start': 127.28, 'duration': 7.24}
# {'text': 'by number 27.', 'start': 130.959, 'duration': 3.561}
# {'text': '[Applause]', 'start': 137.68, 'duration': 11.14}
# {'text': '[Applause]', 'start': 152.54, 'duration': 5.14}
# {'text': 'intercepted and cut out by isla', 'start': 154.239, 'duration': 5.201}
# {'text': 'reclaimed now by', 'start': 157.68, 'duration': 3.919}
# {'text': 'nixon molina', 'start': 159.44, 'duration': 6.96}
# {'text': 'clips it into the box lay off matriarchy', 'start': 161.599, 'duration': 4.801}
# {'text': 'has recovered a lot of', 'start': 166.56, 'duration': 3.679}
# {'text': "lost balls here's gabby goal trying to", 'start': 168.16, 'duration': 4.0}
# {'text': 'one-time it into the path of bruno', 'start': 170.239, 'duration': 3.761}
# {'text': 'enrique', 'start': 172.16, 'duration': 4.079}
# {'text': 'had time to bring it down and shoot it', 'start': 174.0, 'duration': 3.36}
# {'text': "and here's", 'start': 176.239, 'duration': 4.961}
# {'text': 'a second opportunity for number nine', 'start': 177.36, 'duration': 3.84}
# {'text': 'clips', 'start': 181.84, 'duration': 3.759}
# {'text': 'off the crossbar', 'start': 183.599, 'duration': 3.28}
# {'text': "oh that's", 'start': 185.599, 'duration': 3.041}
# {'text': 'good diligent defending from andres', 'start': 186.879, 'duration': 5.041}
# {'text': 'pereira and it was legal too', 'start': 188.64, 'duration': 5.12}
# {'text': 'everything with space in between the', 'start': 191.92, 'duration': 4.56}
# {'text': 'lines heavy touch taken away by riveros', 'start': 193.76, 'duration': 5.92}
# {'text': 'andres pereira off the crossbar once', 'start': 196.48, 'duration': 6.72}
# {'text': "again it's left sides it's a loose pass", 'start': 199.68, 'duration': 5.119}
# {'text': "and it's flamingo in transition with", 'start': 203.2, 'duration': 3.759}
# {'text': 'numerical superiority gabigol bruno', 'start': 204.799, 'duration': 3.52}
# {'text': "enrique is wide open on the left he's", 'start': 206.959, 'duration': 4.081}
# {'text': 'vicino fijino the first time cross and', 'start': 208.319, 'duration': 5.28}
# {'text': 'at the doorstep bruno again backs his', 'start': 211.04, 'duration': 6.88}
# {'text': 'brace and doubles migos leads', 'start': 213.599, 'duration': 4.321}
# {'text': '[Applause]', 'start': 218.79, 'duration': 3.219}
# {'text': 'flamingo are running away with this one', 'start': 222.4, 'duration': 7.52}
# {'text': 'their 28 goals in the competition have', 'start': 227.28, 'duration': 4.4}
# {'text': 'become 30', 'start': 229.92, 'duration': 5.84}
# {'text': 'in less than 45 minutes of play', 'start': 231.68, 'duration': 4.08}
# {'text': 'pounce upon', 'start': 238.0, 'duration': 3.439}
# {'text': 'predatorially', 'start': 239.519, 'duration': 2.541}
# {'text': 'by bruno', 'start': 241.439, 'duration': 2.0}
# {'text': '[Music]', 'start': 242.06, 'duration': 3.539}
# {'text': 'after fantastic work', 'start': 243.439, 'duration': 4.8}
# {'text': 'from gabigal once again and a no-look', 'start': 245.599, 'duration': 4.291}
# {'text': 'pass from virginia', 'start': 248.239, 'duration': 3.601}
# {'text': '[Music]', 'start': 249.89, 'duration': 3.95}
# {'text': 'he could smell bruno herrick his', 'start': 251.84, 'duration': 5.039}
# {'text': 'presence in the box', 'start': 253.84, 'duration': 3.039}
# {'text': 'off to the races', 'start': 261.12, 'duration': 3.76}
# {'text': 'brought down nixon molina is already on', 'start': 263.28, 'duration': 3.68}
# {'text': 'a yellow by the way and he may get his', 'start': 264.88, 'duration': 4.96}
# {'text': 'marching orders', 'start': 266.96, 'duration': 2.88}
# {'text': "that's what renato gaucho wants and he", 'start': 272.0, 'duration': 3.919}
# {'text': 'gets it', 'start': 274.479, 'duration': 4.241}
# {'text': 'well this is absolutely devastating for', 'start': 275.919, 'duration': 4.081}
# {'text': 'barcelona', 'start': 278.72, 'duration': 3.919}
# {'text': 'barcelona were against the ropes taking', 'start': 280.0, 'duration': 4.4}
# {'text': 'punches', 'start': 282.639, 'duration': 4.161}
# {'text': 'and now', 'start': 284.4, 'duration': 2.4}
# {'text': 'they could be on the wrong end of', 'start': 287.199, 'duration': 6.241}
# {'text': 'a beating', 'start': 290.639, 'duration': 2.801}
# {'text': 'it is time to batten down the hatches', 'start': 294.16, 'duration': 3.68}
# {'text': 'minutes without conceding', 'start': 299.12, 'duration': 3.12}
# {'text': 'first 45', 'start': 304.32, 'duration': 4.319}
# {'text': "in the books it's been comprehensive", 'start': 305.84, 'duration': 5.52}
# {'text': "it's been dominant mingao in the lead", 'start': 308.639, 'duration': 4.4}
# {'text': 'two goals to the good at the maracana', 'start': 311.36, 'duration': 3.679}
# {'text': 'against barcelona', 'start': 313.039, 'duration': 3.361}
# {'text': 'in this semi-final first leg of the', 'start': 315.039, 'duration': 4.361}
# {'text': 'libertadores', 'start': 316.4, 'duration': 3.0}
# {'text': 'back underway at the maracana and it is', 'start': 324.32, 'duration': 5.68}
# {'text': 'going better than expected for flamengo', 'start': 326.479, 'duration': 4.72}
# {'text': 'who', 'start': 330.0, 'duration': 3.6}
# {'text': 'have scored twice in this one bruno', 'start': 331.199, 'duration': 5.201}
# {'text': 'enrique with a brace', 'start': 333.6, 'duration': 5.84}
# {'text': 'has now been involved in 27 goals', 'start': 336.4, 'duration': 6.079}
# {'text': 'over the last two', 'start': 339.44, 'duration': 6.0}
# {'text': 'libertadores', 'start': 342.479, 'duration': 2.961}
# {'text': 'martinez will take it', 'start': 346.24, 'duration': 3.2}
# {'text': 'headed out and back in', 'start': 350.639, 'duration': 5.201}
# {'text': 'the shot from carson and big save from', 'start': 353.84, 'duration': 3.44}
# {'text': 'diego elvis', 'start': 355.84, 'duration': 3.199}
# {'text': 'second attempt coming in', 'start': 357.28, 'duration': 3.12}
# {'text': 'all the barcelona players out of', 'start': 359.039, 'duration': 3.681}
# {'text': 'position now everton rivero bruno', 'start': 360.4, 'duration': 5.28}
# {'text': 'enrique vicino to the left gabi goal the', 'start': 362.72, 'duration': 5.199}
# {'text': 'recipient', 'start': 365.68, 'duration': 4.079}
# {'text': 'now to everton ribero clips it towards', 'start': 367.919, 'duration': 5.84}
# {'text': 'the back post vicino blocked', 'start': 369.759, 'duration': 6.56}
# {'text': 'it tries to do it himself but renee has', 'start': 373.759, 'duration': 7.321}
# {'text': 'plenty of pace to make up the ground', 'start': 376.319, 'duration': 4.761}
# {'text': 'given away here by flamingo', 'start': 384.72, 'duration': 4.88}
# {'text': 'castillo', 'start': 386.96, 'duration': 2.64}
# {'text': "he's been an adequate deputy for", 'start': 390.319, 'duration': 4.32}
# {'text': 'philippe luis', 'start': 392.479, 'duration': 5.44}
# {'text': 'rene the 29 year old', 'start': 394.639, 'duration': 4.721}
# {'text': 'haral', 'start': 397.919, 'duration': 2.801}
# {'text': 'gabby goal now', 'start': 399.36, 'duration': 2.72}
# {'text': "he's through", 'start': 400.72, 'duration': 4.8}
# {'text': 'tight angle the suit americana', 'start': 402.08, 'duration': 4.64}
# {'text': 'getting', 'start': 405.52, 'duration': 4.32}
# {'text': 'in see once again', 'start': 406.72, 'duration': 3.12}
# {'text': 'this is good hold up play from', 'start': 410.56, 'duration': 4.4}
# {'text': 'masteriani', 'start': 412.319, 'duration': 4.0}
# {'text': "he's trying to do it all himself he'll", 'start': 414.96, 'duration': 3.6}
# {'text': 'have a pop', 'start': 416.319, 'duration': 4.241}
# {'text': 'rene', 'start': 418.56, 'duration': 4.56}
# {'text': "and they're looking for gabi gold", 'start': 420.56, 'duration': 6.32}
# {'text': "oh he got that one all wrong it's andres", 'start': 423.12, 'duration': 6.4}
# {'text': 'and that is a straight red', 'start': 426.88, 'duration': 4.4}
# {'text': 'and with a couple of minutes left here', 'start': 429.52, 'duration': 3.119}
# {'text': 'perhaps', 'start': 431.28, 'duration': 4.0}
# {'text': 'some daylight for barcelona', 'start': 432.639, 'duration': 4.481}
# {'text': 'just maybe an opportunity to pull one', 'start': 435.28, 'duration': 4.639}
# {'text': 'back at the maracana', 'start': 437.12, 'duration': 5.199}
# {'text': 'hello', 'start': 439.919, 'duration': 2.4}
# {'text': 'can say nothing to defend himself here', 'start': 445.68, 'duration': 4.799}
# {'text': 'it was as clear as day and you just', 'start': 447.919, 'duration': 4.0}
# {'text': "can't get away with that when you have", 'start': 450.479, 'duration': 3.681}
# {'text': 'var', 'start': 451.919, 'duration': 2.241}
# {'text': 'just taking a swipe at fernando leon', 'start': 457.84, 'duration': 4.24}
# {'text': 'but that is the curtain drawn', 'start': 463.52, 'duration': 4.56}
# {'text': 'on this semifinal first leg between', 'start': 465.759, 'duration': 4.961}
# {'text': 'flamingo and barcelona', 'start': 468.08, 'duration': 5.679}
# {'text': 'as andres cuna whistles the game dead', 'start': 470.72, 'duration': 5.36}
# {'text': 'flamengo win it two-nil', 'start': 473.759, 'duration': 3.921}
# {'text': 'bruno', 'start': 476.08, 'duration': 3.36}
# {'text': 'the brace', 'start': 477.68, 'duration': 3.83}
# {'text': 'and the americana', 'start': 479.44, 'duration': 5.089}
# {'text': '[Music]', 'start': 481.51, 'duration': 3.019}
# {'text': '[Music]', 'start': 487.44, 'duration': 3.019}
# {'text': 'you', 'start': 492.08, 'duration': 2.08}
# {'text': 'is no fans here in ecuador', 'start': 0.0, 'duration': 3.919}
# {'text': '[Applause]', 'start': 2.78, 'duration': 2.9}
# {'text': 'of course the government has been', 'start': 3.919, 'duration': 4.081}
# {'text': 'very adamant about that', 'start': 5.68, 'duration': 3.12}
# {'text': 'about', 'start': 8.0, 'duration': 3.28}
# {'text': 'prioritizing vaccination throughout the', 'start': 8.8, 'duration': 5.36}
# {'text': 'country in order to have a certain level', 'start': 11.28, 'duration': 4.399}
# {'text': 'and then when they are able to get to', 'start': 14.16, 'duration': 3.52}
# {'text': 'that level yes then fans will be allowed', 'start': 15.679, 'duration': 2.351}
# {'text': 'in', 'start': 17.68, 'duration': 1.759}
# {'text': '[Music]', 'start': 18.03, 'duration': 6.53}
# {'text': 'he comes over for a 600 000 price tag', 'start': 19.439, 'duration': 7.041}
# {'text': 'and he was officially presented earlier', 'start': 24.56, 'duration': 4.479}
# {'text': "today it's whether they are prioritizing", 'start': 26.48, 'duration': 4.08}
# {'text': 'this competition', 'start': 29.039, 'duration': 3.2}
# {'text': 'you know to have such a poor domestic', 'start': 30.56, 'duration': 2.64}
# {'text': 'form', 'start': 32.239, 'duration': 3.761}
# {'text': 'especially a club of this statue in size', 'start': 33.2, 'duration': 4.96}
# {'text': 'you know managers easily sacrificed', 'start': 36.0, 'duration': 3.76}
# {'text': 'frenchie', 'start': 38.16, 'duration': 4.079}
# {'text': 'swings it out wide holds it back so what', 'start': 39.76, 'duration': 4.56}
# {'text': 'does jaguar do runs to it and he ends up', 'start': 42.239, 'duration': 3.921}
# {'text': 'getting it continuing the move the', 'start': 44.32, 'duration': 2.84}
# {'text': 'movement of the ball', 'start': 46.16, 'duration': 4.559}
# {'text': '[Music]', 'start': 47.16, 'duration': 5.0}
# {'text': 'seen some interesting moves here and', 'start': 50.719, 'duration': 3.36}
# {'text': "there for fluminenses it's leasing he", 'start': 52.16, 'duration': 4.8}
# {'text': 'came from outside', 'start': 54.079, 'duration': 2.881}
# {'text': 'goes back to diaz looking to send it', 'start': 57.28, 'duration': 4.959}
# {'text': 'through cleared away by lucas claro', 'start': 59.199, 'duration': 4.321}
# {'text': "i mean when you're looking at these", 'start': 62.239, 'duration': 2.96}
# {'text': 'passes that diaz is picking off right', 'start': 63.52, 'duration': 2.4}
# {'text': 'now', 'start': 65.199, 'duration': 2.081}
# {'text': 'you just got to get him in around the', 'start': 65.92, 'duration': 3.68}
# {'text': 'box', 'start': 67.28, 'duration': 2.32}
# {'text': 'barcelona with a 2-2 draw would advance', 'start': 69.92, 'duration': 4.64}
# {'text': 'on away goals', 'start': 72.159, 'duration': 5.361}
# {'text': 'great play there goodbye freddie', 'start': 74.56, 'duration': 5.04}
# {'text': 'fantastic skill louis', 'start': 77.52, 'duration': 3.84}
# {'text': 'look how louis and just brings that ball', 'start': 79.6, 'duration': 3.44}
# {'text': 'down', 'start': 81.36, 'duration': 3.52}
# {'text': 'cuts back inside looking to send that', 'start': 83.04, 'duration': 4.079}
# {'text': 'ball', 'start': 84.88, 'duration': 2.239}
# {'text': "projecting it who's going to take that", 'start': 87.52, 'duration': 4.0}
# {'text': 'ball out finally', 'start': 88.88, 'duration': 2.64}
# {'text': 'it was', 'start': 92.4, 'duration': 3.2}
# {'text': 'nixon molina', 'start': 93.6, 'duration': 3.28}
# {'text': "saying okay fine i'll take it here's", 'start': 95.6, 'duration': 3.04}
# {'text': "preciado who's going to take it and he", 'start': 96.88, 'duration': 3.76}
# {'text': 'might end up getting past the defender', 'start': 98.64, 'duration': 4.72}
# {'text': "here's preciado being partied away from", 'start': 100.64, 'duration': 4.159}
# {'text': 'the preciado', 'start': 103.36, 'duration': 2.399}
# {'text': 'of course', 'start': 104.799, 'duration': 2.721}
# {'text': 'prior to that there was a foul being', 'start': 105.759, 'duration': 2.881}
# {'text': 'called', 'start': 107.52, 'duration': 2.639}
# {'text': 'another chance here for fluminenses as', 'start': 108.64, 'duration': 3.519}
# {'text': 'we get into the 38th minute of play ego', 'start': 110.159, 'duration': 3.201}
# {'text': 'one more time', 'start': 112.159, 'duration': 4.64}
# {'text': 'going to the far post reggie', 'start': 113.36, 'duration': 3.439}
# {'text': 'in', 'start': 118.159, 'duration': 4.56}
# {'text': 'taking care of pablo hickey', 'start': 119.28, 'duration': 3.439}
# {'text': 'another deep ball master', 'start': 125.439, 'duration': 6.63}
# {'text': '[Music]', 'start': 128.94, 'duration': 3.129}
# {'text': "it's gonna be a goal kick", 'start': 137.68, 'duration': 2.96}
# {'text': 'as we are', 'start': 139.12, 'duration': 4.16}
# {'text': 'in stoppage time keeping possession', 'start': 140.64, 'duration': 4.08}
# {'text': 'back to diaz', 'start': 143.28, 'duration': 2.4}
# {'text': 'final', 'start': 144.72, 'duration': 3.2}
# {'text': '45 seconds', 'start': 145.68, 'duration': 4.24}
# {'text': 'he just wants that run he as you can see', 'start': 147.92, 'duration': 3.44}
# {'text': 'he wants for seattle to make that', 'start': 149.92, 'duration': 4.48}
# {'text': 'running behind castillo', 'start': 151.36, 'duration': 5.12}
# {'text': 'watch out with benedict', 'start': 154.4, 'duration': 5.28}
# {'text': 'that goes just wide', 'start': 156.48, 'duration': 3.2}
# {'text': 'and many', 'start': 163.68, 'duration': 3.36}
# {'text': 'hearts went into proverbial throats', 'start': 165.04, 'duration': 4.32}
# {'text': 'there on that one', 'start': 167.04, 'duration': 3.919}
# {'text': 'obviously appealing for something there', 'start': 169.36, 'duration': 4.32}
# {'text': 'they felt it was some kind of impedement', 'start': 170.959, 'duration': 3.92}
# {'text': "i'm sure we'll get to have a look at", 'start': 173.68, 'duration': 2.88}
# {'text': 'that again', 'start': 174.879, 'duration': 4.72}
# {'text': 'diaz oh this was making the run but', 'start': 176.56, 'duration': 4.88}
# {'text': 'anticipated', 'start': 179.599, 'duration': 3.601}
# {'text': "incredibly there by someone chevy it'll", 'start': 181.44, 'duration': 5.68}
# {'text': 'be a corner kick coming up for barcelona', 'start': 183.2, 'duration': 3.92}
# {'text': 'keeping it short this time', 'start': 187.28, 'duration': 4.959}
# {'text': 'luminance is staying inside the area now', 'start': 189.04, 'duration': 4.62}
# {'text': 'stop quickly again come on', 'start': 192.239, 'duration': 3.761}
# {'text': '[Music]', 'start': 193.66, 'duration': 4.02}
# {'text': 'just the touch', 'start': 196.0, 'duration': 3.2}
# {'text': 'masteriani waiting making the run down', 'start': 197.68, 'duration': 2.96}
# {'text': 'the near post that goes out wide to', 'start': 199.2, 'duration': 4.16}
# {'text': 'damian diaz has to wait has to set it', 'start': 200.64, 'duration': 4.239}
# {'text': 'the ball does not go through if it did', 'start': 203.36, 'duration': 4.48}
# {'text': 'could have been very dangerous', 'start': 204.879, 'duration': 2.961}
# {'text': '[Music]', 'start': 207.96, 'duration': 4.919}
# {'text': 'back inside', 'start': 209.68, 'duration': 4.559}
# {'text': "it's always", 'start': 212.879, 'duration': 2.881}
# {'text': "it's always a problem you're looking at", 'start': 214.239, 'duration': 3.121}
# {'text': "if you've got a play like diaz if you", 'start': 215.76, 'duration': 4.0}
# {'text': 'just watch that play again receives the', 'start': 217.36, 'duration': 5.2}
# {'text': 'ball and has to show his teammate where', 'start': 219.76, 'duration': 5.28}
# {'text': 'to run', 'start': 222.56, 'duration': 4.72}
# {'text': "making a run looking for diaz here's", 'start': 225.04, 'duration': 3.919}
# {'text': 'damian diaz', 'start': 227.28, 'duration': 3.33}
# {'text': "just didn't get it just right", 'start': 228.959, 'duration': 3.041}
# {'text': '[Applause]', 'start': 230.61, 'duration': 3.47}
# {'text': 'cassandra is dropping back', 'start': 232.0, 'duration': 4.239}
# {'text': 'diego felipe going back and forth and', 'start': 234.08, 'duration': 5.76}
# {'text': 'finally the ball goes over his head', 'start': 236.239, 'duration': 3.601}
# {'text': "here's a good opportunity", 'start': 242.0, 'duration': 3.28}
# {'text': '[Applause]', 'start': 245.35, 'duration': 3.77}
# {'text': '[Music]', 'start': 246.43, 'duration': 3.65}
# {'text': 'it was', 'start': 249.12, 'duration': 2.24}
# {'text': 'that ball', 'start': 250.08, 'duration': 3.2}
# {'text': 'the spin on it', 'start': 251.36, 'duration': 4.159}
# {'text': "because they're fluent as well yeah", 'start': 253.28, 'duration': 3.28}
# {'text': 'advance', 'start': 255.519, 'duration': 3.44}
# {'text': 'well we know what that means', 'start': 256.56, 'duration': 6.48}
# {'text': 'go on say it you want to say it not yet', 'start': 258.959, 'duration': 4.081}
# {'text': 'on there', 'start': 263.44, 'duration': 3.44}
# {'text': 'just took too long there audio says', 'start': 264.72, 'duration': 4.8}
# {'text': 'masteriani', 'start': 266.88, 'duration': 2.64}
# {'text': '[Applause]', 'start': 275.33, 'duration': 4.779}
# {'text': 'what a sensational pass', 'start': 280.8, 'duration': 5.76}
# {'text': 'for gonzalo mastriani', 'start': 284.24, 'duration': 4.08}
# {'text': 'and he makes sure', 'start': 286.56, 'duration': 4.079}
# {'text': "this time that it wasn't offside this", 'start': 288.32, 'duration': 4.48}
# {'text': "time that it doesn't go wide and this", 'start': 290.639, 'duration': 4.241}
# {'text': 'time that it ends up being one nil for', 'start': 292.8, 'duration': 4.16}
# {'text': 'the ecuadorians', 'start': 294.88, 'duration': 4.08}
# {'text': 'when it was coming', 'start': 296.96, 'duration': 4.16}
# {'text': 'it was always coming', 'start': 298.96, 'duration': 3.84}
# {'text': 'barcelona were always the more', 'start': 301.12, 'duration': 4.96}
# {'text': 'aggressive side in this game', 'start': 302.8, 'duration': 5.28}
# {'text': 'not the side being worried about', 'start': 306.08, 'duration': 4.559}
# {'text': 'possession but what a pass', 'start': 308.08, 'duration': 5.679}
# {'text': "what a pass he's clearly on side as well", 'start': 310.639, 'duration': 5.921}
# {'text': 'great pass water touch always keeping an', 'start': 313.759, 'duration': 5.361}
# {'text': 'eye on the ball and because he does it', 'start': 316.56, 'duration': 4.16}
# {'text': 'makes it so much more easy he knows', 'start': 319.12, 'duration': 3.84}
# {'text': "where the goal is he's all eyes all on", 'start': 320.72, 'duration': 4.96}
# {'text': 'the ball to get that first touch right', 'start': 322.96, 'duration': 5.519}
# {'text': 'and puts it into the back of the net', 'start': 325.68, 'duration': 4.239}
# {'text': 'keeping an eye on the ball the whole', 'start': 328.479, 'duration': 4.401}
# {'text': 'time great first touch and pokes it in', 'start': 329.919, 'duration': 6.481}
# {'text': 'fantastic goal come through', 'start': 332.88, 'duration': 6.24}
# {'text': "oh nene's", 'start': 336.4, 'duration': 2.72}
# {'text': '[Applause]', 'start': 355.72, 'duration': 3.919}
# {'text': "i don't think he's had that much room in", 'start': 366.24, 'duration': 3.84}
# {'text': 'the entire match', 'start': 367.52, 'duration': 5.119}
# {'text': 'again crossing signals', 'start': 370.08, 'duration': 4.8}
# {'text': 'and finally a paraguayan is dangerously', 'start': 372.639, 'duration': 4.321}
# {'text': 'sending it in', 'start': 374.88, 'duration': 3.68}
# {'text': "doesn't matter why", 'start': 376.96, 'duration': 5.12}
# {'text': "couldn't send that ball through pineda", 'start': 378.56, 'duration': 3.52}
# {'text': 'final 90 seconds', 'start': 382.479, 'duration': 3.681}
# {'text': 'that one worked', 'start': 384.56, 'duration': 6.68}
# {'text': "here's nino as he's marking quito yeah", 'start': 386.16, 'duration': 5.08}
# {'text': 'why because of this good break coming', 'start': 395.84, 'duration': 4.56}
# {'text': 'here for barcelona', 'start': 398.0, 'duration': 4.4}
# {'text': 'waiting for all the options to open up', 'start': 400.4, 'duration': 5.12}
# {'text': "the chest the shotgun's", 'start': 402.4, 'duration': 3.12}
# {'text': 'but over see', 'start': 407.6, 'duration': 4.08}
# {'text': 'and right now barcelona', 'start': 408.96, 'duration': 4.799}
# {'text': 'the shot in the save by burrai', 'start': 411.68, 'duration': 3.84}
# {'text': 'against guayaquil city', 'start': 413.759, 'duration': 4.401}
# {'text': 'casares', 'start': 415.52, 'duration': 2.64}
# {'text': "who's been", 'start': 418.56, 'duration': 4.96}
# {'text': 'a monster in that backline', 'start': 419.84, 'duration': 3.68}
# {'text': '[Music]', 'start': 429.07, 'duration': 4.849}
# {'text': "we'll need to get maximum points there", 'start': 431.039, 'duration': 6.241}
# {'text': "they'll play bahia shopping", 'start': 433.919, 'duration': 4.961}
# {'text': "it's it's a difficult one because he's", 'start': 437.28, 'duration': 3.28}
# {'text': 'using his hands for elevation and', 'start': 438.88, 'duration': 3.599}
# {'text': "momentum i don't think there's", 'start': 440.56, 'duration': 3.759}
# {'text': 'anything else and for me', 'start': 442.479, 'duration': 4.0}
# {'text': 'is lucas clara really looking to try and', 'start': 444.319, 'duration': 4.521}
# {'text': 'compete to win the ball', 'start': 446.479, 'duration': 4.881}
# {'text': 'there penalty', 'start': 448.84, 'duration': 4.759}
# {'text': 'that was your answer', 'start': 451.36, 'duration': 3.6}
# {'text': 'looking to make it', 'start': 453.599, 'duration': 3.841}
# {'text': 'one off', 'start': 454.96, 'duration': 2.48}
# {'text': "so it's one off with this result", 'start': 458.72, 'duration': 4.4}
# {'text': 'and that is it and i said to finally', 'start': 461.44, 'duration': 3.92}
# {'text': 'kick it again', 'start': 463.12, 'duration': 3.44}
# {'text': 'as', 'start': 465.36, 'duration': 2.88}
# {'text': 'fluminensity', 'start': 466.56, 'duration': 3.919}
# {'text': 'go down', 'start': 468.24, 'duration': 4.399}
# {'text': 'barcelona advance', 'start': 470.479, 'duration': 5.801}
# {'text': 'on away goals', 'start': 472.639, 'duration': 3.641}
# {'text': 'you', 'start': 480.56, 'duration': 2.079}
# {'text': 'will it be four brazilian teams or five', 'start': 1.199, 'duration': 4.001}
# {'text': 'in this case', 'start': 3.36, 'duration': 4.32}
# {'text': 'with the possibility of getting through', 'start': 5.2, 'duration': 4.0}
# {'text': 'or will it be', 'start': 7.68, 'duration': 3.28}
# {'text': 'barcelona brazilian football', 'start': 9.2, 'duration': 3.68}
# {'text': 'confederation but the one in the state', 'start': 10.96, 'duration': 3.36}
# {'text': 'of rio', 'start': 12.88, 'duration': 3.04}
# {'text': 'said the amount of matches that have', 'start': 14.32, 'duration': 3.92}
# {'text': 'been played at maracana by both flamingo', 'start': 15.92, 'duration': 5.119}
# {'text': 'and fluminense have been more than what', 'start': 18.24, 'duration': 4.799}
# {'text': 'a european team', 'start': 21.039, 'duration': 3.681}
# {'text': 'would have played in an entire season', 'start': 23.039, 'duration': 5.441}
# {'text': 'already as the shot goes wide', 'start': 24.72, 'duration': 5.12}
# {'text': 'the ecuadorian trying to serve it into', 'start': 28.48, 'duration': 4.879}
# {'text': 'the area maybe a set piece of work', 'start': 29.84, 'duration': 3.519}
# {'text': 'being absolutely generous', 'start': 40.8, 'duration': 5.36}
# {'text': 'and taking the opportunity and making it', 'start': 43.68, 'duration': 4.08}
# {'text': 'one nil', 'start': 46.16, 'duration': 3.84}
# {'text': 'well this is all about the delivery', 'start': 47.76, 'duration': 4.16}
# {'text': "nothing more than the delivery that's", 'start': 50.0, 'duration': 4.239}
# {'text': 'how important delivery is', 'start': 51.92, 'duration': 5.959}
# {'text': "let's see that again", 'start': 54.239, 'duration': 3.64}
# {'text': "it's a fantastic ball in either way and", 'start': 58.16, 'duration': 4.32}
# {'text': "that's all you want to see", 'start': 60.64, 'duration': 4.159}
# {'text': 'a ball in like that is what causes so', 'start': 62.48, 'duration': 3.92}
# {'text': 'much problems you put it into the area', 'start': 64.799, 'duration': 3.441}
# {'text': 'and give your teammates', 'start': 66.4, 'duration': 5.0}
# {'text': 'an opportunity', 'start': 68.24, 'duration': 3.16}
# {'text': "yep there he's testing the line", 'start': 72.0, 'duration': 3.28}
# {'text': 'yes and a great opportunity to make it', 'start': 76.159, 'duration': 4.401}
# {'text': 'one all in a great', 'start': 78.56, 'duration': 3.599}
# {'text': 'no offside outside', 'start': 80.56, 'duration': 3.44}
# {'text': "well let's see let's see let me see this", 'start': 82.159, 'duration': 4.241}
# {'text': 'i have a doubt is masteriani', 'start': 84.0, 'duration': 4.08}
# {'text': "saying that he was not off side let's", 'start': 86.4, 'duration': 3.6}
# {'text': 'look at this replay', 'start': 88.08, 'duration': 4.16}
# {'text': "it's going to be reviewed by var", 'start': 90.0, 'duration': 3.28}
# {'text': 'right there', 'start': 92.24, 'duration': 1.81}
# {'text': 'yeah', 'start': 93.28, 'duration': 2.56}
# {'text': '[Music]', 'start': 94.05, 'duration': 4.79}
# {'text': 'well as he has nothing to do with the', 'start': 95.84, 'duration': 5.2}
# {'text': 'play and he really will be something', 'start': 98.84, 'duration': 4.52}
# {'text': 'special for us to see', 'start': 101.04, 'duration': 5.68}
# {'text': 'hopefully he has the time and', 'start': 103.36, 'duration': 3.36}
# {'text': 'more continuity in the coaching position', 'start': 107.68, 'duration': 4.479}
# {'text': 'oh as the ball again slips in', 'start': 109.68, 'duration': 3.6}
# {'text': 'the chance', 'start': 112.159, 'duration': 4.721}
# {'text': 'that goes begging is gideo', 'start': 113.28, 'duration': 5.36}
# {'text': 'again', 'start': 116.88, 'duration': 4.32}
# {'text': "a bit more cautious here's casares back", 'start': 118.64, 'duration': 5.92}
# {'text': "to ego it'll be a corner kick for", 'start': 121.2, 'duration': 6.76}
# {'text': 'me nancy', 'start': 124.56, 'duration': 3.4}
# {'text': 'and what made the pass was the fact of', 'start': 128.0, 'duration': 4.879}
# {'text': 'masteriani did not have to bake stride', 'start': 130.479, 'duration': 4.161}
# {'text': 'when he was running forward the pass was', 'start': 132.879, 'duration': 3.36}
# {'text': 'directly in front of what you wanted', 'start': 134.64, 'duration': 4.16}
# {'text': "here's another chance for me nancy", 'start': 136.239, 'duration': 4.221}
# {'text': 'waiting for frankie', 'start': 138.8, 'duration': 3.2}
# {'text': '[Music]', 'start': 140.46, 'duration': 3.54}
# {'text': 'i exactly coincide with what you just', 'start': 142.0, 'duration': 3.68}
# {'text': 'said', 'start': 144.0, 'duration': 2.8}
# {'text': 'one of the', 'start': 145.68, 'duration': 2.48}
# {'text': 'players that', 'start': 146.8, 'duration': 3.68}
# {'text': 'has a lot of expectations put upon him', 'start': 148.16, 'duration': 3.76}
# {'text': 'in ecuadorian football punched away', 'start': 150.48, 'duration': 3.92}
# {'text': 'there by marcos felipe', 'start': 151.92, 'duration': 4.959}
# {'text': 'barcelona now trying to make something', 'start': 154.4, 'duration': 3.839}
# {'text': 'out of this', 'start': 156.879, 'duration': 5.121}
# {'text': 'immediately trying to make an impact', 'start': 158.239, 'duration': 5.561}
# {'text': 'great pass by quesadillas', 'start': 162.0, 'duration': 5.039}
# {'text': '[Music]', 'start': 163.8, 'duration': 3.239}
# {'text': 'castillo', 'start': 168.239, 'duration': 3.681}
# {'text': 'oh', 'start': 170.56, 'duration': 3.759}
# {'text': 'eddie which way possible to clear that', 'start': 171.92, 'duration': 4.72}
# {'text': 'ball', 'start': 174.319, 'duration': 2.321}
# {'text': "coming in it'll be a yellow card", 'start': 176.8, 'duration': 2.48}
# {'text': 'obviously', 'start': 178.319, 'duration': 3.121}
# {'text': 'at the end he wanted', 'start': 179.28, 'duration': 5.28}
# {'text': 'obviously to catch that ball but', 'start': 181.44, 'duration': 5.76}
# {'text': 'scene that he had and you see how he', 'start': 184.56, 'duration': 5.2}
# {'text': 'how martinez comes in on', 'start': 187.2, 'duration': 4.319}
# {'text': 'how well organized they are and how well', 'start': 189.76, 'duration': 3.6}
# {'text': 'drilled they are defensively', 'start': 191.519, 'duration': 2.881}
# {'text': "and they're a team that's very", 'start': 193.36, 'duration': 2.72}
# {'text': 'comfortable to defend without the ball', 'start': 194.4, 'duration': 4.68}
# {'text': 'also', 'start': 196.08, 'duration': 3.0}
# {'text': 'an opportunity to send that ball through', 'start': 204.879, 'duration': 3.601}
# {'text': 'during his', 'start': 207.28, 'duration': 3.679}
# {'text': 'multiple stops during his career over', 'start': 208.48, 'duration': 5.36}
# {'text': 'there', 'start': 210.959, 'duration': 2.881}
# {'text': "he's made his career", 'start': 216.72, 'duration': 3.2}
# {'text': 'oh and the header and the chance that', 'start': 218.48, 'duration': 3.2}
# {'text': 'goes in and', 'start': 219.92, 'duration': 7.56}
# {'text': 'barcelona getting the equalizer adoni', 'start': 221.68, 'duration': 5.8}
# {'text': 'young lad fantastic leap', 'start': 235.04, 'duration': 6.32}
# {'text': 'heads it straight into the ground', 'start': 238.799, 'duration': 4.561}
# {'text': 'but for me again the focal point of that', 'start': 241.36, 'duration': 5.2}
# {'text': 'goal was diaz this pass out wide hair', 'start': 243.36, 'duration': 6.239}
# {'text': 'was absolutely exquisite', 'start': 246.56, 'duration': 6.16}
# {'text': 'when diaz got the ball', 'start': 249.599, 'duration': 3.121}
# {'text': 'i passed it out there', 'start': 253.12, 'duration': 3.119}
# {'text': 'who for me i felt kind of ran out of', 'start': 258.799, 'duration': 4.001}
# {'text': 'ideas and took it back onto his left', 'start': 260.799, 'duration': 4.321}
# {'text': 'foot and dug a cross out', 'start': 262.8, 'duration': 5.32}
# {'text': 'somewhere', 'start': 265.12, 'duration': 3.0}
# {'text': 'instead of continuing play he just', 'start': 269.12, 'duration': 3.519}
# {'text': 'decides to go after him', 'start': 271.04, 'duration': 3.2}
# {'text': 'remember martinez does have a yellow', 'start': 272.639, 'duration': 2.161}
# {'text': 'card', 'start': 274.24, 'duration': 3.759}
# {'text': '[Music]', 'start': 274.8, 'duration': 3.199}
# {'text': "oh he's gone so", 'start': 280.32, 'duration': 4.24}
# {'text': 'the man that got the yellow card earlier', 'start': 284.8, 'duration': 4.399}
# {'text': 'on the man that comes up with the assist', 'start': 286.72, 'duration': 3.52}
# {'text': 'now the man that comes up with his', 'start': 289.199, 'duration': 2.961}
# {'text': 'second yellow part of the match and puts', 'start': 290.24, 'duration': 3.84}
# {'text': 'his team in a real difficult position', 'start': 292.16, 'duration': 3.52}
# {'text': 'now', 'start': 294.08, 'duration': 4.08}
# {'text': 'with 15 minutes to go', 'start': 295.68, 'duration': 4.48}
# {'text': 'no need to go to ground there', 'start': 298.16, 'duration': 3.92}
# {'text': "yeah and it's it's a it's a definitely a", 'start': 300.16, 'duration': 4.879}
# {'text': "booking it's a yellow card", 'start': 302.08, 'duration': 4.8}
# {'text': 'very very silly challenge kicks him', 'start': 305.039, 'duration': 4.0}
# {'text': 'right up in the knees lucky because that', 'start': 306.88, 'duration': 3.84}
# {'text': 'could even be reviewed to be a straight', 'start': 309.039, 'duration': 3.521}
# {'text': "red and now you're presenting them with", 'start': 310.72, 'duration': 5.36}
# {'text': 'opportunities to attack your goal again', 'start': 312.56, 'duration': 3.52}
# {'text': 'inside and finally cleared away', 'start': 316.16, 'duration': 7.56}
# {'text': 'scrambling around kaicki', 'start': 319.68, 'duration': 4.04}
# {'text': 'you hear how frantic', 'start': 324.88, 'duration': 5.68}
# {'text': 'the barcelona defense is', 'start': 327.28, 'duration': 5.359}
# {'text': 'good pass by', 'start': 330.56, 'duration': 3.76}
# {'text': 'felipe', 'start': 332.639, 'duration': 4.161}
# {'text': 'another cross looking inside and just', 'start': 334.32, 'duration': 4.56}
# {'text': "getting in each other's way", 'start': 336.8, 'duration': 4.399}
# {'text': 'you take him off you bringing it forward', 'start': 338.88, 'duration': 5.52}
# {'text': 'and number nine may i add', 'start': 341.199, 'duration': 6.961}
# {'text': 'a penalty inside the area', 'start': 344.4, 'duration': 5.28}
# {'text': 'pleading his innocence there not', 'start': 348.16, 'duration': 3.44}
# {'text': 'claiming it to be a penalty', 'start': 349.68, 'duration': 3.359}
# {'text': "but i'm sure players already know that", 'start': 351.6, 'duration': 3.52}
# {'text': "it's going to be right there you see", 'start': 353.039, 'duration': 3.121}
# {'text': 'yeah', 'start': 355.12, 'duration': 2.96}
# {'text': "he's impeding him", 'start': 356.16, 'duration': 3.759}
# {'text': "to be able to right there nino's", 'start': 358.08, 'duration': 4.239}
# {'text': 'completely impeding him', 'start': 359.919, 'duration': 5.12}
# {'text': 'dramatic moment here', 'start': 362.319, 'duration': 5.361}
# {'text': "it'll be cortes looking for the lead oh", 'start': 365.039, 'duration': 7.041}
# {'text': 'no it just gets passed', 'start': 367.68, 'duration': 7.12}
# {'text': 'just gets past marcos philippe 2-1', 'start': 372.08, 'duration': 5.119}
# {'text': 'barcelona', 'start': 374.8, 'duration': 4.72}
# {'text': 'felipe guesses the right way but i just', 'start': 377.199, 'duration': 3.921}
# {'text': "think there's just", 'start': 379.52, 'duration': 3.92}
# {'text': 'enough power to get it', 'start': 381.12, 'duration': 4.799}
# {'text': 'under him', 'start': 383.44, 'duration': 3.36}
# {'text': 'oh', 'start': 385.919, 'duration': 2.801}
# {'text': 'felipe should have saved that and he', 'start': 386.8, 'duration': 3.679}
# {'text': 'knows it', 'start': 388.72, 'duration': 4.24}
# {'text': 'should have saved that right height not', 'start': 390.479, 'duration': 5.681}
# {'text': 'great amount of power there', 'start': 392.96, 'duration': 5.44}
# {'text': "just doesn't get his hands to it alexis", 'start': 396.16, 'duration': 4.4}
# {'text': 'herrera says play on despite the protest', 'start': 398.4, 'duration': 3.359}
# {'text': 'from freddie', 'start': 400.56, 'duration': 3.28}
# {'text': 'despite the protest from nene', 'start': 401.759, 'duration': 3.841}
# {'text': 'looking to get one more looking to set', 'start': 403.84, 'duration': 5.44}
# {'text': 'that ball inside abe hernandez', 'start': 405.6, 'duration': 3.68}
# {'text': 'well i think either or i think for me', 'start': 414.56, 'duration': 3.919}
# {'text': 'personally the referee was waiting', 'start': 416.319, 'duration': 4.88}
# {'text': 'for var to intervene', 'start': 418.479, 'duration': 4.321}
# {'text': 'to give him a decision on whether it was', 'start': 421.199, 'duration': 3.201}
# {'text': "a handball or not he didn't want to stop", 'start': 422.8, 'duration': 3.36}
# {'text': 'the play', 'start': 424.4, 'duration': 3.359}
# {'text': 'and he found the perfect situation to do', 'start': 426.16, 'duration': 3.039}
# {'text': 'it', 'start': 427.759, 'duration': 2.801}
# {'text': 'but without not having to make a', 'start': 429.199, 'duration': 3.521}
# {'text': 'decision', 'start': 430.56, 'duration': 4.28}
# {'text': "let's see i know we're going to see it", 'start': 432.72, 'duration': 5.599}
# {'text': 'now yep hundred percent', 'start': 434.84, 'duration': 4.57}
# {'text': "here's freddie", 'start': 438.319, 'duration': 4.23}
# {'text': '[Music]', 'start': 439.41, 'duration': 3.139}
# {'text': 'koshavis and he says he pushed', 'start': 444.8, 'duration': 5.28}
# {'text': "i have to see i don't know what they're", 'start': 448.639, 'duration': 2.721}
# {'text': 'talking about the push maybe there was', 'start': 450.08, 'duration': 2.399}
# {'text': 'something that occurred at the line', 'start': 451.36, 'duration': 3.44}
# {'text': "let's see", 'start': 452.479, 'duration': 2.321}
# {'text': 'no encroachment', 'start': 455.52, 'duration': 2.16}
# {'text': 'no', 'start': 456.8, 'duration': 3.36}
# {'text': 'fantastic penalty there by freddy', 'start': 457.68, 'duration': 6.32}
# {'text': 'barcelona just got a great result', 'start': 460.16, 'duration': 6.159}
# {'text': 'maybe not as great as they had before', 'start': 464.0, 'duration': 3.68}
# {'text': 'the 93rd', 'start': 466.319, 'duration': 6.041}
# {'text': 'in the 93rd minute it was even better', 'start': 467.68, 'duration': 4.68}
#
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=gsiBERz7Jrw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# {'text': 'a look inside the estadio monumental', 'start': 0.719, 'duration': 4.64}
# {'text': 'inaugurated with both', 'start': 3.48, 'duration': 5.56}
# {'text': 'sets of players coming on to the pitch', 'start': 5.359, 'duration': 6.961}
# {'text': 'at the same time the players respected', 'start': 9.04, 'duration': 4.32}
# {'text': 'the silence the', 'start': 12.32, 'duration': 3.199}
# {'text': 'supporters outside the stadium wanting', 'start': 13.36, 'duration': 3.919}
# {'text': 'to make their presence felt theirs we', 'start': 15.519, 'duration': 3.441}
# {'text': 'had fireworks', 'start': 17.279, 'duration': 3.92}
# {'text': "outside as we're underway here in", 'start': 18.96, 'duration': 3.92}
# {'text': 'guayaquil ecuador', 'start': 21.199, 'duration': 5.92}
# {'text': 'for barcelona against velez', 'start': 22.88, 'duration': 6.08}
# {'text': 'gabriel cordes scored at the weekend', 'start': 27.119, 'duration': 4.111}
# {'text': 'against makara in the league', 'start': 28.96, 'duration': 5.119}
# {'text': '[Music]', 'start': 31.23, 'duration': 5.65}
# {'text': 'straight into the', 'start': 34.079, 'duration': 2.801}
# {'text': 'gabriel cortes will', 'start': 38.559, 'duration': 7.281}
# {'text': 'take this corner', 'start': 41.6, 'duration': 4.24}
# {'text': "he didn't have it covered if it just", 'start': 53.92, 'duration': 5.04}
# {'text': 'been a tiny bit lower', 'start': 55.6, 'duration': 5.36}
# {'text': "there's that time the cross goes", 'start': 58.96, 'duration': 4.239}
# {'text': 'harmlessly through to', 'start': 60.96, 'duration': 4.88}
# {'text': 'lucas', 'start': 63.199, 'duration': 2.641}
# {'text': '[Music]', 'start': 66.97, 'duration': 2.95}
# {'text': 'loses out he was trying to shield the', 'start': 68.479, 'duration': 3.361}
# {'text': "ball but he's instead lost possession a", 'start': 69.92, 'duration': 3.12}
# {'text': 'bit of space now for', 'start': 71.84, 'duration': 4.88}
# {'text': 'centurion still with centurion', 'start': 73.04, 'duration': 6.16}
# {'text': "does he's done well there just slightly", 'start': 76.72, 'duration': 3.84}
# {'text': 'cut short there but man question keeps', 'start': 79.2, 'duration': 4.48}
# {'text': "it going it's a good ball in front", 'start': 80.56, 'duration': 5.68}
# {'text': 'figure up in the air both in defense and', 'start': 83.68, 'duration': 4.4}
# {'text': 'in attack here come', 'start': 86.24, 'duration': 6.0}
# {'text': 'barcelona cortes forced to go back', 'start': 88.08, 'duration': 6.719}
# {'text': 'he links up nicely with nixon molina', 'start': 92.24, 'duration': 3.68}
# {'text': "it's a good ball from", 'start': 94.799, 'duration': 4.0}
# {'text': "cortes opportunity here oh they've done", 'start': 95.92, 'duration': 3.519}
# {'text': 'it', 'start': 98.799, 'duration': 3.68}
# {'text': 'barcelona are back on level terms and', 'start': 99.439, 'duration': 5.521}
# {'text': "it's adonis preciado with his first", 'start': 102.479, 'duration': 5.28}
# {'text': 'ever goal in the copper libertadores so', 'start': 104.96, 'duration': 5.04}
# {'text': 'it is faith in', 'start': 107.759, 'duration': 8.081}
# {'text': 'the 24 year old', 'start': 110.0, 'duration': 5.84}
# {'text': 'and it worked to perfection cortes with', 'start': 116.159, 'duration': 5.201}
# {'text': "that pass that just opens up ellis's", 'start': 119.6, 'duration': 2.559}
# {'text': 'defense', 'start': 121.36, 'duration': 3.359}
# {'text': 'garces holds the ball up nicely does', 'start': 122.159, 'duration': 6.16}
# {'text': 'just enough something pretty special', 'start': 124.719, 'duration': 7.361}
# {'text': 'to score from there slight opening here', 'start': 128.319, 'duration': 5.92}
# {'text': 'as fernando leon brings it forward', 'start': 132.08, 'duration': 6.159}
# {'text': "he two goes for goal oh it's just wide", 'start': 134.239, 'duration': 9.601}
# {'text': "open didn't move", 'start': 138.239, 'duration': 5.601}
# ...
# {'text': 'last elite 8 that the tournament begins', 'start': 60.03, 'duration': 5.13}
# {'text': 'to define itself in comparison to', 'start': 62.7, 'duration': 6.059}
# {'text': 'previous World Cups are we lost in the', 'start': 65.16, 'duration': 6.209}
# {'text': "exuberance amidst Brazil's ribcage", 'start': 68.759, 'duration': 5.041}
# {'text': 'bursting sorweful further for its be', 'start': 71.369, 'duration': 3.051}
# {'text': 'loved again', 'start': 73.8, 'duration': 2.88}
# {'text': 'Brazil is pervading the most glorious', 'start': 74.42, 'duration': 5.35}
# {'text': 'stage of volcano of Mortain emotion for', 'start': 76.68, 'duration': 5.49}
# {'text': 'the teams and football east as to skip', 'start': 79.77, 'duration': 4.65}
# {'text': 'the light Fandango and produced football', 'start': 82.17, 'duration': 5.94}
# {'text': 'of the highest octane and yet for all', 'start': 84.42, 'duration': 6.03}
# {'text': 'the stunning memories amassed so far we', 'start': 88.11, 'duration': 4.799}
# {'text': 'have yet to see one single team emerge', 'start': 90.45, 'duration': 5.55}
# {'text': 'with the aura of exceptional about them', 'start': 92.909, 'duration': 6.931}
# {'text': 'so far it may prove to be that a magical', 'start': 96.0, 'duration': 6.33}
# {'text': 'team produces a supernova finale with a', 'start': 99.84, 'duration': 4.47}
# {'text': 'storyline that history will look back on', 'start': 102.33, 'duration': 4.56}
# {'text': "and say that's why Brazil 14 was a truly", 'start': 104.31, 'duration': 4.769}
# {'text': 'great World Cup many of the usual', 'start': 106.89, 'duration': 4.589}
# {'text': 'suspects are still there again but they', 'start': 109.079, 'duration': 4.981}
# {'text': 'are looking for their top gear will it', 'start': 111.479, 'duration': 5.011}
# {'text': 'be a Cinderella story for the ages when', 'start': 114.06, 'duration': 4.62}
# {'text': 'one of the little outsiders wear the', 'start': 116.49, 'duration': 5.04}
# {'text': "crown or one of the team's so massively", 'start': 118.68, 'duration': 5.79}
# {'text': 'dependent of one genius of a player to', 'start': 121.53, 'duration': 5.4}
# {'text': 'drag them by their boot laces to', 'start': 124.47, 'duration': 4.23}
# {'text': 'ultimate glory and overcome the', 'start': 126.93, 'duration': 4.44}
# {'text': 'gargantuan pressure of expectation and', 'start': 128.7, 'duration': 6.349}
# {'text': "you know who I'm talking about", 'start': 131.37, 'duration': 7.17}
# {'text': "hey I'm loving this World Cup but the", 'start': 135.049, 'duration': 6.071}
# {'text': 'great ones the truly great World Cups', 'start': 138.54, 'duration': 5.73}
# {'text': 'give us a team and a hero that proves to', 'start': 141.12, 'duration': 6.9}
# {'text': 'be inhibited a unique and dazzling', 'start': 144.27, 'duration': 6.21}
# {'text': 'so far that team has yet to present', 'start': 148.02, 'duration': 9.11}
# {'text': 'itself and so Ali here again vámanos', 'start': 150.48, 'duration': 6.65}
# {'text': 'I just want to see it sincerely to', 'start': 0.0, 'duration': 4.319}
# {'text': "Shakira thank you so much and i'm very", 'start': 2.159, 'duration': 4.531}
# {'text': "proud that you're a fan of maine it", 'start': 4.319, 'duration': 6.211}
# {'text': 'means a lot to me and vamonos lost covet', 'start': 6.69, 'duration': 8.18}
# {'text': 'arrows and also of this abasa', 'start': 10.53, 'duration': 4.34}
# {'text': 'watching this World Cup on the telly', 'start': 18.44, 'duration': 5.17}
# {'text': 'took me down memory lane and had me', 'start': 20.64, 'duration': 4.95}
# {'text': 'reminiscing about the glittering stars', 'start': 23.61, 'duration': 3.899}
# {'text': 'that have graced past World Cups and', 'start': 25.59, 'duration': 5.25}
# {'text': "some that didn't I am very fortunate to", 'start': 27.509, 'duration': 5.761}
# {'text': 'have cleared alongside and against some', 'start': 30.84, 'duration': 4.62}
# {'text': 'of the gods of the game players who', 'start': 33.27, 'duration': 4.2}
# {'text': 'skipped the light fantastic at the', 'start': 35.46, 'duration': 4.65}
# {'text': "world's highest profile tournament the", 'start': 37.47, 'duration': 4.4}
# {'text': 'World Cup', 'start': 40.11, 'duration': 4.949}
# {'text': "it's strange now thinking back to the", 'start': 41.87, 'duration': 4.899}
# {'text': 'was Halcyon dears when I was a', 'start': 45.059, 'duration': 4.5}
# {'text': 'footballer playing on the same pitch and', 'start': 46.769, 'duration': 5.31}
# {'text': 'in training with footballs and morals', 'start': 49.559, 'duration': 6.031}
# {'text': 'like good mullah till field could be us', 'start': 52.079, 'duration': 5.16}
# {'text': 'George best', 'start': 55.59, 'duration': 5.43}
# {'text': 'Elias Figueroa Mourinho Chagas Gordon', 'start': 57.239, 'duration': 6.451}
# {'text': 'banks being friends with them all', 'start': 61.02, 'duration': 5.25}
# {'text': 'somehow took away some of the Stardust', 'start': 63.69, 'duration': 5.52}
# {'text': 'around them but when we were in a game', 'start': 66.27, 'duration': 5.7}
# {'text': 'that Stardust reappeared all around them', 'start': 69.21, 'duration': 4.049}
# {'text': 'again and you remembered what', 'start': 71.97, 'duration': 4.56}
# {'text': 'world-class company you were in from', 'start': 73.259, 'duration': 5.341}
# {'text': 'those lads only George never played in a', 'start': 76.53, 'duration': 5.64}
# {'text': 'World Cup very sadly another teammate of', 'start': 78.6, 'duration': 6.269}
# {'text': "mine who didn't was Yan van Beveren the", 'start': 82.17, 'duration': 4.23}
# {'text': 'greatest keeper Holland has ever', 'start': 84.869, 'duration': 2.161}
# {'text': 'produced', 'start': 86.4, 'duration': 3.27}
# {'text': 'and who would surely have helped them', 'start': 87.03, 'duration': 5.37}
# {'text': 'win their two World Cup finals had he', 'start': 89.67, 'duration': 6.23}
# {'text': 'not had a nasty feud with Johan Cruyff', 'start': 92.4, 'duration': 6.24}
# {'text': 'glancing back at the memorable matches', 'start': 95.9, 'duration': 5.289}
# {'text': 'these battle Royals that we had against', 'start': 98.64, 'duration': 4.019}
# {'text': 'Christ Pelle', 'start': 101.189, 'duration': 4.561}
# {'text': 'Beckenbauer Alan Ball wim van hanegem', 'start': 102.659, 'duration': 6.871}
# {'text': 'Carlos Alberto you savior has been a', 'start': 105.75, 'duration': 11.04}
# {'text': "rude crowd your hand miss khun's Oh some", 'start': 109.53, 'duration': 10.199}
# {'text': 'things truly like the gods there was one', 'start': 116.79, 'duration': 4.59}
# {'text': "game I'll never forget and with good", 'start': 119.729, 'duration': 3.511}
# {'text': 'reason when my Fort Lauderdale Strikers', 'start': 121.38, 'duration': 5.34}
# {'text': 'played against a New York Cosmos that', 'start': 123.24, 'duration': 5.43}
# {'text': 'night there were seven World Cup', 'start': 126.72, 'duration': 4.549}
# {'text': 'captains on the pitch at the same time', 'start': 128.67, 'duration': 6.8}
# {'text': 'guess who got Man of the Match', 'start': 131.269, 'duration': 4.201}
# {'text': "they're here remember that great lame", 'start': 18.23, 'duration': 5.77}
# {'text': 'from poltergeist where that we had', 'start': 21.75, 'duration': 5.46}
# {'text': 'spooky kid can see the ghosts if only we', 'start': 24.0, 'duration': 5.189}
# {'text': 'all could see the supernatural other', 'start': 27.21, 'duration': 5.1}
# {'text': 'future here but would you really want to', 'start': 29.189, 'duration': 6.471}
# {'text': 'know I mean really would you not me', 'start': 32.31, 'duration': 6.03}
# {'text': 'anticipation is a wonderful sensation', 'start': 35.66, 'duration': 4.329}
# {'text': 'like waiting for Santa Claus at', 'start': 38.34, 'duration': 4.32}
# {'text': "Christmas now we're waiting for Santa", 'start': 39.989, 'duration': 7.471}
# {'text': 'Claus in Brazil this world cup brings a', 'start': 42.66, 'duration': 7.68}
# {'text': 'truckload of unknowns in mysteries and I', 'start': 47.46, 'duration': 5.69}
# {'text': "love it but there's no crystal ball in", 'start': 50.34, 'duration': 5.46}
# {'text': 'the crucible of Brazil the intense', 'start': 53.15, 'duration': 5.74}
# {'text': 'pressure and expectations will elevate a', 'start': 55.8, 'duration': 5.91}
# {'text': 'decimate national parade all around the', 'start': 58.89, 'duration': 5.519}
# {'text': "planet we've had some poor world cups in", 'start': 61.71, 'duration': 5.4}
# {'text': 'recent past so I pray that with the game', 'start': 64.409, 'duration': 5.011}
# {'text': 'back in its spiritual home we say', 'start': 67.11, 'duration': 4.77}
# {'text': 'Stardust football because Sambolin', 'start': 69.42, 'duration': 4.29}
# {'text': 'deserves it after what they have given', 'start': 71.88, 'duration': 4.949}
# {'text': 'us over the decades the enormous sense', 'start': 73.71, 'duration': 5.01}
# {'text': 'of anticipation for the famous yellow', 'start': 76.829, 'duration': 4.071}
# {'text': 'shirts those cannery nose is', 'start': 78.72, 'duration': 4.92}
# {'text': 'overwhelming and no other horse nation', 'start': 80.9, 'duration': 5.5}
# {'text': 'ever has had such a gargantuan burden of', 'start': 83.64, 'duration': 5.28}
# {'text': 'responsibility placed on them to win it', 'start': 86.4, 'duration': 5.1}
# {'text': 'all second place will be a failure and', 'start': 88.92, 'duration': 5.37}
# {'text': 'the danger is that better Brazilian', 'start': 91.5, 'duration': 7.05}
# {'text': 'teams in this one have field Argentina a', 'start': 94.29, 'duration': 6.75}
# {'text': "Brazil's eternal enemy and would love", 'start': 98.55, 'duration': 4.74}
# {'text': 'nothing more than seeing the greatest', 'start': 101.04, 'duration': 4.619}
# {'text': 'player of his generation messy eclipse', 'start': 103.29, 'duration': 5.64}
# {'text': 'his teammate from Barcelona nema the', 'start': 105.659, 'duration': 5.581}
# {'text': 'argies are more dangerous in attack then', 'start': 108.93, 'duration': 4.619}
# {'text': 'dark fear as Death Star but we all know', 'start': 111.24, 'duration': 4.08}
# {'text': "what happened to that cuz it didn't have", 'start': 113.549, 'duration': 4.701}
# {'text': 'a defense and Luke Skywalker blew it up', 'start': 115.32, 'duration': 5.19}
# {'text': 'spin will be healed as the greatest', 'start': 118.25, 'duration': 5.02}
# {'text': 'national team ever if santika Casillas', 'start': 120.51, 'duration': 5.55}
# {'text': 'hoists the golden trophy eclipsing in', 'start': 123.27, 'duration': 5.639}
# {'text': 'the land of Pelle that and more or', 'start': 126.06, 'duration': 5.67}
# {'text': 'nineteen seventy team imagine that by', 'start': 128.909, 'duration': 4.381}
# {'text': 'the way why is it called of World Cup', 'start': 131.73, 'duration': 6.089}
# {'text': "anymore it's not even a cup belgium", 'start': 133.29, 'duration': 7.05}
# {'text': 'columbia uruguay and netherlands', 'start': 137.819, 'duration': 4.621}
# {'text': 'threatened to rise above previous', 'start': 140.34, 'duration': 4.47}
# {'text': 'efforts while france england in italy', 'start': 142.44, 'duration': 4.42}
# {'text': 'all previous winners tried', 'start': 144.81, 'duration': 4.3}
# {'text': 'reinvent themselves who the hell knows', 'start': 146.86, 'duration': 5.31}
# {'text': 'what to expect from those three USAF', 'start': 149.11, 'duration': 6.0}
# {'text': 'Mexico Portugal Ghana could create more', 'start': 152.17, 'duration': 5.73}
# {'text': 'shocks than a bad electrician Ivory', 'start': 155.11, 'duration': 5.15}
# {'text': 'Coast and chili could spark a revolution', 'start': 157.9, 'duration': 6.06}
# {'text': "they're here all right but who wins it", 'start': 160.26, 'duration': 7.8}
# {'text': 'all Germany', 'start': 163.96, 'duration': 4.1}
# {'text': 'the qualification wrote to the world cup', 'start': 18.08, 'duration': 5.17}
# {'text': 'finals is as treacherous as sladon donor', 'start': 20.91, 'duration': 6.72}
# {'text': 'razor blade pressure expectations', 'start': 23.25, 'duration': 6.57}
# {'text': 'overcoming all sorts of adversities and', 'start': 27.63, 'duration': 5.22}
# {'text': 'challenges and disappointments you think', 'start': 29.82, 'duration': 5.4}
# {'text': 'that the managers of the final 32 would', 'start': 32.85, 'duration': 5.639}
# {'text': 'be able to exhale and enjoy refining', 'start': 35.22, 'duration': 4.859}
# {'text': "their team's once they've booked their", 'start': 38.489, 'duration': 4.531}
# {'text': 'ticket to Brazil well that lasts about a', 'start': 40.079, 'duration': 5.25}
# {'text': 'week and then the pressure starts', 'start': 43.02, 'duration': 4.38}
# {'text': 'ratcheting up again all under the', 'start': 45.329, 'duration': 4.861}
# {'text': 'scrutiny of parties and fans all who', 'start': 47.4, 'duration': 6.32}
# {'text': 'want every step to escalate the belief', 'start': 50.19, 'duration': 6.36}
# {'text': 'these so-called friendlies often seem to', 'start': 53.72, 'duration': 5.29}
# {'text': 'create more questions and introduce more', 'start': 56.55, 'duration': 4.5}
# {'text': "doubts than if they didn't play them at", 'start': 59.01, 'duration': 3.96}
# {'text': 'all but they are essential to', 'start': 61.05, 'duration': 3.81}
# {'text': 'determining just what the coach wants', 'start': 62.97, 'duration': 5.43}
# {'text': 'out of his team these serious dress', 'start': 64.86, 'duration': 6.81}
# {'text': 'rehearsals if they go well can fuel team', 'start': 68.4, 'duration': 5.329}
# {'text': 'belief and instill confidence and', 'start': 71.67, 'duration': 4.08}
# {'text': 'individual players and the team', 'start': 73.729, 'duration': 4.601}
# {'text': 'collective or they can plant the first', 'start': 75.75, 'duration': 5.28}
# {'text': 'seeds of true doubt from the boss to the', 'start': 78.33, 'duration': 5.55}
# {'text': 'players alike create an anxiety in the', 'start': 81.03, 'duration': 5.37}
# {'text': "Mane's of the fans navigating this", 'start': 83.88, 'duration': 4.59}
# {'text': "crucial course is like solving a Rubik's", 'start': 86.4, 'duration': 3.81}
# {'text': 'Cube with one arm tied behind your back', 'start': 88.47, 'duration': 4.74}
# {'text': 'the regiment of hard training mixes with', 'start': 90.21, 'duration': 5.46}
# {'text': 'a high-profile international match the', 'start': 93.21, 'duration': 4.68}
# {'text': 'variation of team selection the', 'start': 95.67, 'duration': 4.41}
# {'text': 'necessity to create a pattern of play', 'start': 97.89, 'duration': 5.1}
# {'text': 'amongst the squad of players that is', 'start': 100.08, 'duration': 5.64}
# {'text': 'still in a state of flux and all the', 'start': 102.99, 'duration': 4.919}
# {'text': 'whale not giving away too much of your', 'start': 105.72, 'duration': 4.53}
# {'text': "team's strategy which would clear your", 'start': 107.909, 'duration': 5.311}
# {'text': 'ponens hands come short aim how do you', 'start': 110.25, 'duration': 5.25}
# {'text': 'conceal your true aces up your sleeve', 'start': 113.22, 'duration': 6.93}
# {'text': 'given all of this and the final run of', 'start': 115.5, 'duration': 6.78}
# {'text': 'optimism can feared as quickly as a', 'start': 120.15, 'duration': 4.23}
# {'text': "rainbow on a summer's day if more", 'start': 122.28, 'duration': 4.68}
# {'text': 'targets are missed then hits but how', 'start': 124.38, 'duration': 5.609}
# {'text': "crucial is it really Italy didn't have", 'start': 126.96, 'duration': 6.389}
# {'text': 'it in 2006 and they want it Columbia had', 'start': 129.989, 'duration': 6.181}
# {'text': 'too much of it in 1994 and their crashed', 'start': 133.349, 'duration': 5.941}
# {'text': "and burned don't put too much stock in", 'start': 136.17, 'duration': 5.19}
# {'text': 'these exhibitions ahead of the real', 'start': 139.29, 'duration': 4.77}
# {'text': 'torture test come the World Cup the', 'start': 141.36, 'duration': 4.83}
# {'text': 'expression in showbiz is that a bad', 'start': 144.06, 'duration': 2.94}
# {'text': 'rehearsal', 'start': 146.19, 'duration': 4.08}
# {'text': 'will lead to a grand performance there', 'start': 147.0, 'duration': 7.97}
# {'text': 'again the opposite is often the case', 'start': 150.27, 'duration': 4.7}
